# %%
# Approach: 
# create list of 10 cities
# download OSM data for each city
# extract buildings from OSM data
# extract coordinate bounds for each city
# download with openeo Sentinel-2 data for each city
# plot for each city OSM map, sentinel-2, single-band, overlapping buildings and URB

from pyrosm import OSM
from pyrosm import get_data

# Investigate: train model with cities from different continents
cities = ['Berlin', 'Bonn', 'London', 'Manchester', 'Paris', 'Marseille', 'Madrid', 'Barcelona', 'Rome', 'Mailand']

def download_osm_data(city):
    """
    Download OSM data for a given city
    """
    fp = get_data(city)
    return fp


def get_buildings(fp):
    """
    Get buildings from OSM data
    """
    osm = OSM(fp)
    buildings = osm.get_buildings()
    return buildings


def extract_coordinate_bounds(city):
    """
    Extract coordinate bounds for a given city
    """
    pass


def download_sentinel_data(city):
    """
    Download Sentinel-2 data for a given city
    """
    pass


def plot(city):
    """
    Plot all pictures for a given city
    """
    pass


for city in cities:
    download_osm_data(city)
    get_buildings(city)
    extract_coordinate_bounds(city)
    download_sentinel_data(city)
    plot(city)
